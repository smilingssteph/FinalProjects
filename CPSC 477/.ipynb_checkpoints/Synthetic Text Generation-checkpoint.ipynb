# %%
import numpy as np
import pandas as pd
import jsonlines
import csv

import tensorflow as tf
tf.config.run_functions_eagerly(True)

from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Flatten, Lambda
from tensorflow.keras.losses import binary_crossentropy, categorical_crossentropy
from keras import ops

from sklearn.preprocessing import label_binarize

import nltk
nltk.download("stopwords")
import string
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sh2482\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
file = "data/aspect-level-certainty.jsonl"

annotate_science = []

with jsonlines.open(file) as f:
    for line in f.iter():
        annotate_science.append(line)

# %%
finance = pd.read_csv("data/10K_sentiment_list.csv")
uncertain_finance = finance[finance["Uncertainty"] != 0]["Word"].values

# %%
# Restructure annotated data from scientific set
label_codes = {"NotPresent": 0, "Certain": 1, "Uncertain": 2}
dims = {"Number": None, "Extent": None, "Probability": None, "Condition": None, "Suggestion": None, "Framing": None}
real_text = [x["finding"] for x in annotate_science]
real_labels = [[label_codes[x["aspect-level-certainty"][dim]] for dim in dim_order] for x in annotate_science]


with open("text_train", 'w') as csvfile:
    writer = csv.writer(csvfile, fieldnames=fields)
 
    # writing headers (field names)
    writer.writeheader()
 
    # writing data rows
    writer.writerows(mydict)

# %%
latent_dim = 100
embedding_dim = 128
num_label_dims = 6
one_hot_len = 3
label_values = [0,1,2]
max_len = 64
lstm_units = 64

# %%
def preprocess(text):
    """
    Preprocesses text string by removing capitalization, punctuation, and stop words.

    Args:
        text: The text string to be preprocessed.

    Returns:
        The preprocessed text string.
    """

    text = text.lower()
    text = "".join(c for c in text if c not in string.punctuation)
    stop_words = stopwords.words("english")
    text = " ".join([word for word in text.split() if word not in stop_words])
    return text

# %%
def tokenize(text, max_len):
    """
    Tokenizes preprocessed text string.

    Args:
        text: The preprocessed text string.
        max_len: The maximum length for tokenized sequences

    Returns:
        A list of integers representing the tokenized text sequence.
    """

    tokenizer = Tokenizer(num_words=vocab_size)
    tokenizer.fit_on_texts([text])
    sequences = tokenizer.texts_to_sequences([text])
    if len(sequences) > max_len:
        sequences = sequences[:max_len]
    else:
        sequences = tf.keras.utils.pad_sequences(sequences, max_len, padding="post")
    return sequences

# %%
domain_weight = 0.2

def generator_loss(y_true, y_pred):
    """
    Calculates a custom loss function.

    Args:
        y_true: The ground truth labels.
        y_pred: The predicted labels.
        domain_weight: The weight for finance specific uncertainty loss.

    Returns:
        The combined loss value.
    """
    text_loss = categorical_crossentropy(y_true, y_pred)

    # Make sure to use same embeddings as generator model
    embedding_layer = generator.get_layer('embedding') 
    word_embedding_matrix = embedding_layer.get_weights()[0]

    finance_word_embeddings = tf.nn.embedding_lookup(word_embedding_matrix, finance_token)
    uncertainty_scores = tf.reduce_mean(finance_word_embeddings, axis=1)
    uncertainty_loss = tf.reduce_mean(tf.abs(uncertainty_scores - y_true[:, 1]))
    return text_loss + uncertainty_loss * domain_weight

# %%
def discriminator_loss(real_output, fake_output):
    """
    Calculates loss function to distinguish between real and fake text.

    Args:
        real_output: The real text.
        fake_output: The generated tex.

    Returns:
        The loss value.
    """
    real_loss = binary_crossentropy(tf.ones_like(real_output), real_output)
    fake_loss = binary_crossentropy(tf.zeros_like(fake_output), fake_output)
    label_loss = binary_crossentropy(real_output, fake_output)
    return real_loss + fake_loss + label_loss

# %% [markdown]
# ### Build the Model

# %%
def build_generator():
    noise_input = Input(shape=(latent_dim,))
    label_input = Input(shape=(one_hot_len,))
    combined = Concatenate()([noise_input, label_input])
    embedded = Embedding(vocab_size, embedding_dim, name="embedding")(combined)
    lstm1 = LSTM(256, return_sequences=True)(embedded)
    lstm2 = LSTM(128)(lstm1)
    output = Dense(max_len, activation='softmax')(lstm2)
    model = Model(inputs=[noise_input, label_input], outputs=output)
    model.compile(loss = generator_loss, optimizer="adam")
    return model

# %%
def build_discriminator():
    text_input = Input(shape=(None,))
    label_input = Input(shape=(one_hot_len,))
    combined = Concatenate()([text_input, label_input])
    embedded = Embedding(vocab_size, embedding_dim)(combined)
    lstm1 = LSTM(256, return_sequences=True)(embedded)
    lstm2 = LSTM(128)(lstm1)
    sentiment_output = Dense(1, activation='sigmoid')(lstm2)
    model = Model(inputs=[text_input, label_input], outputs=sentiment_output)
    model.compile(loss = discriminator_loss, optimizer="adam")
    return model

# %%
def build_combined():
    noise_input = Input(shape=(latent_dim,))
    sentiment_input = Input(shape=(one_hot_len,))
    generated_text = generator([noise_input, sentiment_input])
    validity = discriminator([generated_text, sentiment_input])
    model = Model(inputs=[noise_input, sentiment_input], outputs=validity)
    model.compile(loss="categorical_crossentropy", optimizer="adam")
    return model

# %%
real_text_process = [preprocess(x) for x in real_text]
real_text_token = [tokenize(x, max_len) for x in real_text_process]

finance_text_process = [preprocess(x) for x in uncertain_finance]
finance_token = [tokenize(x, max_len) for x in finance_text_process]

one_hot_labels = [label_binarize(x, classes=[0,1,2]) for x in real_labels]

dims["Number"] = [x[0] for x in one_hot_labels]
dims["Extent"] = [x[1] for x in one_hot_labels]
dims["Probability"] = [x[2] for x in one_hot_labels]
dims["Condition"] = [x[3] for x in one_hot_labels]
dims["Suggestion"] = [x[4] for x in one_hot_labels]
dims["Framing"] = [x[5] for x in one_hot_labels]

# %%
num_epochs = 16
batch_size = 64

num_batches = len(real_text_token) // batch_size

generator = build_generator()
discriminator = build_discriminator()
combined = build_combined()

real = np.ones((batch_size, 1))
fake = np.zeros((batch_size, 1))

all_d_loss = [[0 for x in range(num_batches)] for y in range(num_epochs)]
all_gen_loss = [[0 for x in range(num_batches)] for y in range(num_epochs)]

for epoch in range(num_epochs):
    for i in range(num_batches):
        
        start = i * batch_size
        end = (i + 1) * batch_size
        
        real_data = tf.convert_to_tensor(real_text_token[start:end])
        real_data_labels = tf.convert_to_tensor(dims["Number"][start:end])
        
        # Train Discriminator
        noise_data = tf.convert_to_tensor(np.random.normal(size=(batch_size, latent_dim)))
        generate_labels = tf.convert_to_tensor(np.random.randint(0, 2, size=(batch_size, one_hot_len)))

        generated_data = tf.convert_to_tensor(generator.predict([noise_data, generate_labels]))
        real_data = Flatten()(real_data)
        
        real_loss = discriminator.train_on_batch([real_data, generate_labels], real)
        fake_loss = discriminator.train_on_batch([generated_data, generate_labels], fake)
        d_loss = 0.5 * np.add(real_loss, fake_loss)

        all_d_loss[epoch][i] = d_loss
        
        # Train Generator        
        gen_loss = combined.train_on_batch([noise_data, real_data_labels], real)

        all_gen_loss[epoch][i] = gen_loss
    
        # Print training progress
    print(f"Epoch: {epoch+1}/{num_epochs}, Discriminator Loss: {d_loss}, Generator Loss: {gen_loss[0]}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 891ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 884ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[508], line 39
#      36 all_d_loss[epoch][i] = d_loss
#      38 # Train Generator
# ---> 39 gen_loss = combined.train_on_batch([noise_data, real_data_labels], real)
#      41 all_gen_loss[epoch][i] = gen_loss
#      43 # Print training progress
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:540, in TensorFlowTrainer.train_on_batch(self, x, y, sample_weight, class_weight, return_dict)
#     537 def data():
#     538     yield (x, y, sample_weight)
# --> 540 logs = self.train_function(data())
#     541 logs = tree.map_structure(lambda x: np.array(x), logs)
#     542 if return_dict:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:810, in Function.__call__(self, *args, **kwds)
#     808 if self._run_functions_eagerly:
#     809   with trace.Trace(self._name, tf_function_call="eager"):
# --> 810     return self._python_function(*args, **kwds)
#     812 # Only count the statistics the first time, before initialization took
#     813 # place.
#     814 if self._created_variables is None:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:117, in TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator(iterator)
#     115 """Runs a single training step given a Dataset iterator."""
#     116 data = next(iterator)
# --> 117 outputs = self.distribute_strategy.run(
#     118     one_step_on_data, args=(data,)
#     119 )
#     120 outputs = reduce_per_replica(
#     121     outputs,
#     122     self.distribute_strategy,
#     123     reduction="auto",
#     124 )
#     125 return outputs
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1673, in StrategyBase.run(***failed resolving arguments***)
#    1668 with self.scope():
#    1669   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1670   # applied when the caller is also in Eager mode.
#    1671   fn = autograph.tf_convert(
#    1672       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1673   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3263, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    3261   kwargs = {}
#    3262 with self._container_strategy().scope():
# -> 3263   return self._call_for_each_replica(fn, args, kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:4061, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    4059 def _call_for_each_replica(self, fn, args, kwargs):
#    4060   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4061     return fn(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:810, in Function.__call__(self, *args, **kwds)
#     808 if self._run_functions_eagerly:
#     809   with trace.Trace(self._name, tf_function_call="eager"):
# --> 810     return self._python_function(*args, **kwds)
#     812 # Only count the statistics the first time, before initialization took
#     813 # place.
#     814 if self._created_variables is None:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:104, in TensorFlowTrainer.make_train_function.<locals>.one_step_on_data(data)
#     101 @tf.autograph.experimental.do_not_convert
#     102 def one_step_on_data(data):
#     103     """Runs a single training step on a batch of data."""
# --> 104     return self.train_step(data)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:51, in TensorFlowTrainer.train_step(self, data)
#      49 with tf.GradientTape() as tape:
#      50     if self._call_has_training_arg:
# ---> 51         y_pred = self(x, training=True)
#      52     else:
#      53         y_pred = self(x)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\layer.py:846, in Layer.__call__(self, *args, **kwargs)
#     844         outputs = super().__call__(*args, **kwargs)
#     845 else:
# --> 846     outputs = super().__call__(*args, **kwargs)
#     847 # Change the layout for the layer output if needed.
#     848 # This is useful for relayout intermediate tensor in the model
#     849 # to achieve the optimal performance.
#     850 distribution = distribution_lib.distribution()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\ops\operation.py:48, in Operation.__call__(self, *args, **kwargs)
#      43             call_fn = self.call
#      44     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      45         call_fn,
#      46         object_name=(f"{self.__class__.__name__}.call()"),
#      47     )
# ---> 48     return call_fn(*args, **kwargs)
#      50 # Plain flow.
#      51 if any_symbolic_tensors(args, kwargs):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\models\functional.py:202, in Functional.call(self, inputs, training, mask)
#     200         if mask is not None:
#     201             x._keras_mask = mask
# --> 202 outputs = self._run_through_graph(
#     203     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     204 )
#     205 return unpack_singleton(outputs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\ops\function.py:155, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     153     outputs = call_fn(op, *args, **kwargs)
#     154 else:
# --> 155     outputs = op(*args, **kwargs)
#     157 # Update tensor_dict.
#     158 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\models\functional.py:592, in operation_fn.<locals>.call(*args, **kwargs)
#     586 if (
#     587     hasattr(operation, "_call_has_training_arg")
#     588     and operation._call_has_training_arg
#     589     and training is not None
#     590 ):
#     591     kwargs["training"] = training
# --> 592 return operation(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\layer.py:846, in Layer.__call__(self, *args, **kwargs)
#     844         outputs = super().__call__(*args, **kwargs)
#     845 else:
# --> 846     outputs = super().__call__(*args, **kwargs)
#     847 # Change the layout for the layer output if needed.
#     848 # This is useful for relayout intermediate tensor in the model
#     849 # to achieve the optimal performance.
#     850 distribution = distribution_lib.distribution()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\ops\operation.py:48, in Operation.__call__(self, *args, **kwargs)
#      43             call_fn = self.call
#      44     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      45         call_fn,
#      46         object_name=(f"{self.__class__.__name__}.call()"),
#      47     )
# ---> 48     return call_fn(*args, **kwargs)
#      50 # Plain flow.
#      51 if any_symbolic_tensors(args, kwargs):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\models\functional.py:202, in Functional.call(self, inputs, training, mask)
#     200         if mask is not None:
#     201             x._keras_mask = mask
# --> 202 outputs = self._run_through_graph(
#     203     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     204 )
#     205 return unpack_singleton(outputs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\ops\function.py:155, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     153     outputs = call_fn(op, *args, **kwargs)
#     154 else:
# --> 155     outputs = op(*args, **kwargs)
#     157 # Update tensor_dict.
#     158 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\models\functional.py:592, in operation_fn.<locals>.call(*args, **kwargs)
#     586 if (
#     587     hasattr(operation, "_call_has_training_arg")
#     588     and operation._call_has_training_arg
#     589     and training is not None
#     590 ):
#     591     kwargs["training"] = training
# --> 592 return operation(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\layer.py:846, in Layer.__call__(self, *args, **kwargs)
#     844         outputs = super().__call__(*args, **kwargs)
#     845 else:
# --> 846     outputs = super().__call__(*args, **kwargs)
#     847 # Change the layout for the layer output if needed.
#     848 # This is useful for relayout intermediate tensor in the model
#     849 # to achieve the optimal performance.
#     850 distribution = distribution_lib.distribution()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\ops\operation.py:48, in Operation.__call__(self, *args, **kwargs)
#      43             call_fn = self.call
#      44     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      45         call_fn,
#      46         object_name=(f"{self.__class__.__name__}.call()"),
#      47     )
# ---> 48     return call_fn(*args, **kwargs)
#      50 # Plain flow.
#      51 if any_symbolic_tensors(args, kwargs):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\rnn\lstm.py:560, in LSTM.call(self, sequences, initial_state, mask, training)
#     559 def call(self, sequences, initial_state=None, mask=None, training=False):
# --> 560     return super().call(
#     561         sequences, mask=mask, training=training, initial_state=initial_state
#     562     )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:406, in RNN.call(self, sequences, initial_state, mask, training)
#     400 # Prepopulate the dropout state so that the inner_loop is stateless
#     401 # this is particularly important for JAX backend.
#     402 self._maybe_config_dropout_masks(
#     403     self.cell, sequences[:, 0, :], initial_state
#     404 )
# --> 406 last_output, outputs, states = self.inner_loop(
#     407     sequences=sequences,
#     408     initial_state=initial_state,
#     409     mask=mask,
#     410     training=training,
#     411 )
#     412 last_output = ops.cast(last_output, self.compute_dtype)
#     413 outputs = ops.cast(outputs, self.compute_dtype)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\rnn\lstm.py:555, in LSTM.inner_loop(self, sequences, initial_state, mask, training)
#     548 if self.use_cudnn is True:
#     549     raise ValueError(
#     550         "use_cudnn=True was specified, "
#     551         "but cuDNN is not supported for this layer configuration "
#     552         "with this backend. Pass use_cudnn='auto' to fallback "
#     553         "to a non-cuDNN implementation."
#     554     )
# --> 555 return super().inner_loop(
#     556     sequences, initial_state, mask=mask, training=training
#     557 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:346, in RNN.inner_loop(self, sequences, initial_state, mask, training)
#     343 if not tree.is_nested(initial_state):
#     344     initial_state = [initial_state]
# --> 346 return backend.rnn(
#     347     step,
#     348     sequences,
#     349     initial_state,
#     350     go_backwards=self.go_backwards,
#     351     mask=mask,
#     352     unroll=self.unroll,
#     353     input_length=sequences.shape[1],
#     354     zero_output_for_mask=self.zero_output_for_mask,
#     355     return_all_outputs=self.return_sequences,
#     356 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\rnn.py:428, in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask, return_all_outputs)
#     423         new_states = tree.pack_sequence_as(
#     424             initial_states, flat_new_state
#     425         )
#     426         return (time + 1, output_ta_t) + tuple(new_states)
# --> 428     final_outputs = tf.while_loop(
#     429         body=_step,
#     430         loop_vars=(time, output_ta) + states,
#     431         **while_loop_kwargs,
#     432     )
#     433     new_states = final_outputs[2:]
#     435 output_ta = final_outputs[1]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\util\deprecation.py:660, in deprecated_arg_values.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     652           _PRINTED_WARNING[(func, arg_name)] = True
#     653         _log_deprecation(
#     654             'From %s: calling %s (from %s) with %s=%s is deprecated and '
#     655             'will be removed %s.\nInstructions for updating:\n%s',
#    (...)
#     658             'in a future version' if date is None else
#     659             ('after %s' % date), instructions)
# --> 660 return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\ops\while_loop.py:241, in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#      35 @tf_export("while_loop", v1=[])
#      36 @deprecation.deprecated_arg_values(
#      37     None,
#    (...)
#      52                   maximum_iterations=None,
#      53                   name=None):
#      54   """Repeat `body` while the condition `cond` is true.
#      55
#      56   Note: This op is automatically used in a `tf.function` to convert Python for-
#    (...)
#     239
#     240   """
# --> 241   return while_loop(
#     242       cond=cond,
#     243       body=body,
#     244       loop_vars=loop_vars,
#     245       shape_invariants=shape_invariants,
#     246       parallel_iterations=parallel_iterations,
#     247       back_prop=back_prop,
#     248       swap_memory=swap_memory,
#     249       name=name,
#     250       maximum_iterations=maximum_iterations,
#     251       return_same_structure=True)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\ops\while_loop.py:488, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#     485 loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#     486                                         list(loop_vars))
#     487 while cond(*loop_vars):
# --> 488   loop_vars = body(*loop_vars)
#     489   if try_to_pack and not isinstance(loop_vars, (list, tuple)):
#     490     packed = True
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\ops\while_loop.py:479, in while_loop.<locals>.<lambda>(i, lv)
#     476     loop_vars = (counter, loop_vars)
#     477     cond = lambda i, lv: (  # pylint: disable=g-long-lambda
#     478         math_ops.logical_and(i < maximum_iterations, orig_cond(*lv)))
# --> 479     body = lambda i, lv: (i + 1, orig_body(*lv))
#     480   try_to_pack = False
#     482 if executing_eagerly:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\rnn.py:411, in rnn.<locals>._step(time, output_ta_t, *states)
#     409 current_input = tuple(ta.read(time) for ta in input_ta)
#     410 current_input = tree.pack_sequence_as(inputs, current_input)
# --> 411 output, new_states = step_function(
#     412     current_input, tuple(states) + tuple(constants)
#     413 )
#     414 flat_new_state = tree.flatten(new_states)
#     416 flat_output = tree.flatten(output)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:338, in RNN.inner_loop.<locals>.step(inputs, states)
#     337 def step(inputs, states):
# --> 338     output, new_states = self.cell(inputs, states, **cell_kwargs)
#     339     if not tree.is_nested(new_states):
#     340         new_states = [new_states]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\layer.py:846, in Layer.__call__(self, *args, **kwargs)
#     844         outputs = super().__call__(*args, **kwargs)
#     845 else:
# --> 846     outputs = super().__call__(*args, **kwargs)
#     847 # Change the layout for the layer output if needed.
#     848 # This is useful for relayout intermediate tensor in the model
#     849 # to achieve the optimal performance.
#     850 distribution = distribution_lib.distribution()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\ops\operation.py:48, in Operation.__call__(self, *args, **kwargs)
#      43             call_fn = self.call
#      44     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      45         call_fn,
#      46         object_name=(f"{self.__class__.__name__}.call()"),
#      47     )
# ---> 48     return call_fn(*args, **kwargs)
#      50 # Plain flow.
#      51 if any_symbolic_tensors(args, kwargs):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\rnn\lstm.py:264, in LSTMCell.call(self, inputs, states, training)
#     262     c, o = self._compute_carry_and_output(x, h_tm1, c_tm1)
#     263 else:
# --> 264     z = ops.matmul(inputs, self.kernel)
#     266     z += ops.matmul(h_tm1, self.recurrent_kernel)
#     267     if self.use_bias:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\ops\numpy.py:3440, in matmul(x1, x2)
#    3438 if any_symbolic_tensors((x1, x2)):
#    3439     return Matmul().symbolic_call(x1, x2)
# -> 3440 return backend.numpy.matmul(x1, x2)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\numpy.py:375, in matmul(x1, x2)
#     373     output_type = None
#     374 x1 = tf.cast(x1, compute_dtype)
# --> 375 x2 = tf.cast(x2, compute_dtype)
#     377 def with_combined_batch_dimensions(a, b, output_shape, fn_3d):
#     378     a_sparse = isinstance(a, tf.SparseTensor)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\ops\math_ops.py:1010, in cast(x, dtype, name)
#    1004   x = indexed_slices.IndexedSlices(values_cast, x.indices, x.dense_shape)
#    1005 else:
#    1006   # TODO(josh11b): If x is not already a Tensor, we could return
#    1007   # ops.convert_to_tensor(x, dtype=dtype, ...)  here, but that
#    1008   # allows some conversions that cast() can't do, e.g. casting numbers to
#    1009   # strings.
# -> 1010   x = ops.convert_to_tensor(x, name="x")
#    1011   if x.dtype.is_complex and base_type.is_floating:
#    1012     logging.warn(
#    1013         f"You are casting an input of type {x.dtype.name} to an "
#    1014         f"incompatible dtype {base_type.name}.  This will "
#    1015         "discard the imaginary part and may not be what you "
#    1016         "intended."
#    1017     )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:713, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     711 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     712 preferred_dtype = preferred_dtype or dtype_hint
# --> 713 return tensor_conversion_registry.convert(
#     714     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     715 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:209, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     207 overload = getattr(value, "__tf_tensor__", None)
#     208 if overload is not None:
# --> 209   return overload(dtype, name)  #  pylint: disable=not-callable
#     211 for base_type, conversion_func in get(type(value)):
#     212   # If dtype is None but preferred_dtype is not None, we try to
#     213   # cast to preferred_dtype first.
#     214   ret = None
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:65, in Variable.__tf_tensor__(self, dtype, name)
#      64 def __tf_tensor__(self, dtype=None, name=None):
# ---> 65     return tf.convert_to_tensor(self.value, dtype=dtype, name=name)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\framework\tensor_conversion.py:161, in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#      96 @tf_export.tf_export("convert_to_tensor", v1=[])
#      97 @dispatch.add_dispatch_support
#      98 def convert_to_tensor_v2_with_dispatch(
#      99     value, dtype=None, dtype_hint=None, name=None
#     100 ) -> tensor_lib.Tensor:
#     101   """Converts the given `value` to a `Tensor`.
#     102
#     103   This function converts Python objects of various types to `Tensor`
#    (...)
#     159     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#     160   """
# --> 161   return convert_to_tensor_v2(
#     162       value, dtype=dtype, dtype_hint=dtype_hint, name=name
#     163   )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\framework\tensor_conversion.py:171, in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#     169 """Converts the given `value` to a `Tensor`."""
#     170 # preferred_dtype = preferred_dtype or dtype_hint
# --> 171 return tensor_conversion_registry.convert(
#     172     value, dtype, name, preferred_dtype=dtype_hint
#     173 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:2331, in _dense_var_to_tensor(var, dtype, name, as_ref)
#    2330 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 2331   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1577, in BaseResourceVariable._dense_var_to_tensor(***failed resolving arguments***)
#    1575   return self.read_value().op.inputs[0]
#    1576 else:
# -> 1577   return self.value()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:629, in BaseResourceVariable.value(self)
#     627   return self._cached_value
#     628 with ops.colocate_with(None, ignore_existing=True):
# --> 629   return self._read_variable_op()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:813, in BaseResourceVariable._read_variable_op(self, no_copy)
#     811       result = read_and_set_handle(no_copy)
#     812 else:
# --> 813   result = read_and_set_handle(no_copy)
#     815 if not context.executing_eagerly():
#     816   # Note that if a control flow context is active the input of the read op
#     817   # might not actually be the handle. This line bypasses it.
#     818   record.record_operation(
#     819       "ReadVariableOp", [result], [self.handle],
#     820       backward_function=lambda x: [x],
#     821       forward_function=lambda x: [x])
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:803, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     801 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     802   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 803 result = gen_resource_variable_ops.read_variable_op(
#     804     self.handle, self._dtype)
#     805 _maybe_set_handle_data(self._dtype, self.handle, result)
#     806 return result
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:535, in read_variable_op(resource, dtype, name)
#     533 if tld.is_eager:
#     534   try:
# --> 535     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     536       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     537     return _result
#     538   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
